# %% [markdown]
# <a href="https://colab.research.google.com/github/Edisonsoaresonly/PA-1F-grupo-A/blob/main/Aula_dia_31_03_PA_1F_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estrutura de decisões

# Escrever um programa que recebe o nome e a idade do usuário e verifica se o usuário é criança, adolescente e adulto

# >= 12 anos é criança
# =< 17 anos é adolescente
# Adulto

# Entrada

nome = str(input("digite o seu nome: "))
idade = int(input("digite sua idade: "))

# Processamento / Saída

if idade <= 12:
 print(f"{nome}, você tem {idade} anos de idade, você é criança.")

elif idade <= 17:
  print(f"{nome}, você tem {idade} anos de idade, você é adolescente.")

else:
  print(f"{nome}, você tem {idade} anos de idade, você é adulto.")
# Out:
# digite o seu nome: Lewis Hamilton
# digite sua idade: 31
# Lewis Hamilton, você tem 31 anos de idade, você é adulto.

# %%
# Em um jogo, um personagem possui uma variavel chamada energia. O programa deve: Se a energia for maior que 70 - Forte, se a energia estiver entre 30 e 70 - Cansado, se a energia estiver menor que 30 - Fraco.

# Entrada

Energia = int(input("digite a energia do seu personagem: "))

# Processamento

if Energia <= 30:
  print(f"Seu personagem tem energia igual a {Energia}. Ele está fraco.")

elif Energia <= 70:
  print(f"Seu personagem tem energia igual a {Energia}. Ele está cansado.")

else:
   print(f"Seu personagem tem energia igual a {Energia}. Ele está forte.")
# Out:
# digite a energia do seu personagem: 100
# Seu personagem tem energia igual a 100. Ele está forte.

# %%
# @title
# Escrever um programa que classifica os tipos de triângulo e valida se é um triângulo.

# Validar se lados digitados pode formar um triângulo
# lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1

# Tipos de triângulo
# Equilatero - todos os lados iguais - ==
# Escaleno - todos os lados diferentes - !=
# Isóceles - dois lados iguais

# Entrada
lado1 = float(input("digite o lado do triângulo: "))
lado2 = float(input("digite o lado do triângulo: "))
lado3 = float(input("digite o lado do triângulo: "))

# Verifica se é um triângulo válido
if (lado1 + lado2 > lado3) and (lado1 + lado3 > lado2) and (lado2 + lado3 > lado1):

  if lado1 == lado2 and lado2 == lado3:
    print("Triângulo Equilátero")

  elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3:
    print("Triângulo Escaleno")

  else:
    print("Triângulo Isósceles")

else:
  print("Não é um triângulo válido")
# Out:
# digite o lado do triângulo: 10
# digite o lado do triângulo: 9
# digite o lado do triângulo: 8
# Triângulo Escaleno
