# %% [markdown]
# <a href="https://colab.research.google.com/github/Edisonsoaresonly/PA-1F-grupo-A/blob/main/HelloWord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Olá Mundo")
# Out:
# Olá Mundo
